# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05ch-RP/NASSCOM/blob/main/WEEK1/Writing_and_Using_Functions_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🔹 1. DEFINING A BASIC FUNCTION

# A function is a block of code that performs a task and can be reused.

def greet():
    print("HelloOOOOOOOOO! Welcome to Python Functions.")

# Calling the function
greet()
# Out:
# HelloOOOOOOOOO! Welcome to Python Functions.

# %%
# 🔹 2. FUNCTION WITH PARAMETERS

def greet_user(name):
    print(f"Hello, {name}!")

greet_user("PRANAVI")
greet_user("REDDY")  # You can reuse the function with different arguments
# Out:
# Hello, PRANAVI!
# Hello, REDDY!

# %%
# 🔹 3. FUNCTION WITH DEFAULT PARAMETERS

def greet_user(name="WELCOME"):
    print(f"Welcome, {name}!")

greet_user()         # Uses default
greet_user("REDDY PRANAVI")   # Overrides default
# Out:
# Welcome, WELCOME!
# Welcome, REDDY PRANAVI!

# %%
# 🔹 5. USING *args (VARIABLE NUMBER OF POSITIONAL ARGUMENTS)

# *args lets you pass any number of positional arguments as a tuple

def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("PRANAVI", "PRANATHI", "ANASUYA", "PRAVEEN")
# Out:
# Names passed: ('PRANAVI', 'PRANATHI', 'ANASUYA', 'PRAVEEN')
# Hello PRANAVI
# Hello PRANATHI
# Hello ANASUYA
# Hello PRAVEEN

# %%
# 🔹 6. USING **kwargs (VARIABLE NUMBER OF KEYWORD ARGUMENTS)

# **kwargs lets you pass any number of keyword arguments as a dictionary

def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="PRANAVI", age=18, city="NZB")
# Out:
# User Info:
# name = PRANAVI
# age = 18
# city = NZB

# %%
# 🔹 7. COMBINING *args AND **kwargs

def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="PRANAVI", city="Mumbai")
# Out:
# Args: (1, 2, 3)
# Kwargs: {'name': 'PRANAVI', 'city': 'Mumbai'}

# %%
# 🔹 8. FUNCTION NESTING (CALL ONE FUNCTION INSIDE ANOTHER)

def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 9:", square(9))
# Out:
# Square of 9: 81
